# %% [markdown]
# <a href="https://colab.research.google.com/github/clemcou-socio/23Rcode/blob/master/Code_C23_vRmagic_github.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Code des analyses présentées dans la partie 2 du chapitre 23
# ##Écrit par Éric Lacourse, Véronique Dupéré et Charles-Édouard Giguère
# ###Analyste: Charles-Édouard Giguère
# ###Transcription du code: Clémentine Courdi

# %%
# Activer R magic
# %load_ext rpy2.ipython
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython

# %%
# !git clone https://github.com/clemcou-socio/23Rcode.git
# Out:
# fatal: destination path '23Rcode' already exists and is not an empty directory.

# %%
import pandas as pd
SD = pd.read_csv('23Rcode/SD.csv') 
print(SD.head(5))
# Out:
#    Unnamed: 0  ID  ECOLE  ...  LOW269DICO  LOW2912DICO  CHRONSEVACT
# 0         367   1     14  ...           0            0            0
# 1         368   2     14  ...           1            1            1
# 2         369   3     14  ...           1            1            0
# 3         370   4     14  ...           1            1            0
# 4         371   5     14  ...           0            0            1
#
# [5 rows x 36 columns]

# %%
# %%R #Activer code R pour la cellule
#
# #Téléchargement des packages nécessaire à l'analyse
# install.packages("CUFF") #Package CUFF (Charles's Utility Function using Formula) pour affichage des variables
# install.packages ("dplyr") #Package dplyr pour manipulation flexible des données
# install.packages("ggplot2")#Package ggplot2 pour création de graphiques
# install.packages("haven") #Package haven pour importer des données d'autres formats dans R
#
# require(dplyr, quietly = TRUE, warn.conflicts = FALSE) #Package dplyr pour manipulation flexible des données
# require(ggplot2, quietly = TRUE, warn.conflicts = FALSE) #Package ggplot2 pour création de graphiques
# require(CUFF, quietly = TRUE, warn.conflicts = FALSE) #Package CUFF (Charles's Utility Function using Formula) pour affichage des variables
# require(haven, quietly = TRUE, warn.conflicts = FALSE) #Package haven pour importer des données d'autres formats dans R
# Out:
# R[write to console]: Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# R[write to console]: also installing the dependencies ‘minqa’, ‘nloptr’, ‘statmod’, ‘RcppEigen’, ‘zip’, ‘lme4’, ‘numDeriv’, ‘openxlsx’, ‘xtable’, ‘lmerTest’
#
#
# R[write to console]: trying URL 'https://cran.rstudio.com/src/contrib/minqa_1.2.4.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 53548 bytes (52 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# ...

# %%
# %%R #Activer code R pour la cellule
#
# library(readr)
# SD <- read_csv("23Rcode/SD.csv")
# ls(SD)
#  #Identifier l'ensemble de données à utiliser  #Identifier l'ensemble de données à utiliser
# Out:
# R[write to console]: Parsed with column specification:
# cols(
#   .default = col_double()
# )
#
# R[write to console]: See spec(...) for full column specifications.
#  [1] "ADAPT"         "AGE"           "AIMES"         "AMB"
#  [5] "CHRONSEVACT"   "DOUBLE"        "ECOLE"         "EVDISTMOD"
#  [9] "EVDISTSEV"     "ID"            "IMP"           "LOW203DICO"
# [13] "LOW236DICO"    "LOW269DICO"    "LOW2912DICO"   "MALE"
# [17] "MINORITY"      "MODER203DICO"  "MODER236DICO"  "MODER269DICO"
# [21] "MODER2912DICO" "NOTES_FR"      "NOTES_MATH"    "PAR_IMM"
# [25] "PAR_SEP"       "PR_AUTRES"     "SCOLMAX"       "SEVER03DICO"
# [29] "SEVER36DICO"   "SEVER69DICO"   "SEVER912DICO"  "SRDQ"
# [33] "STATUT"        "TRAVAILM"      "TRAVAILP"      "X1"

# %%
# %%R
#
# TRAIN.df <- SD[1:700,] ; TEST.df <- SD[701:1000,] #Créer un sous-ensemble de données d'entrainement et de données de test
#
# ls (TRAIN.df)
#
# ls (TEST.df)
# Out:
#  [1] "ADAPT"         "AGE"           "AIMES"         "AMB"
#  [5] "CHRONSEVACT"   "DOUBLE"        "ECOLE"         "EVDISTMOD"
#  [9] "EVDISTSEV"     "ID"            "IMP"           "LOW203DICO"
# [13] "LOW236DICO"    "LOW269DICO"    "LOW2912DICO"   "MALE"
# [17] "MINORITY"      "MODER203DICO"  "MODER236DICO"  "MODER269DICO"
# [21] "MODER2912DICO" "NOTES_FR"      "NOTES_MATH"    "PAR_IMM"
# [25] "PAR_SEP"       "PR_AUTRES"     "SCOLMAX"       "SEVER03DICO"
# [29] "SEVER36DICO"   "SEVER69DICO"   "SEVER912DICO"  "SRDQ"
# [33] "STATUT"        "TRAVAILM"      "TRAVAILP"      "X1"

# %% [markdown]
# Liens utilisés:
#
# https://www.youtube.com/watch?v=oqMImCeXi6o&list=WL&index=5&t=162s
#
# https://stackoverflow.com/questions/46155300/pydrive-error-no-downloadlink-exportlinks-for-mimetype-found-in-metadata
#
# https://www.youtube.com/watch?v=58t0PFIWR9Y
